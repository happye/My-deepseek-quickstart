# %% [markdown]
# # DeepSeek Agent 实战：小红书爆款文案生成助手
#
# 本 Notebook 将指导您如何使用 DeepSeek LLM 构建一个能够生成小红书爆款文案的智能 Agent。我们将从需求拆解开始，逐步定义 Agent 的系统提示词 (System Prompt)、外部工具 (Tools)，并实现其核心的工作流程，最终生成符合小红书平台特点的文案。
#
# ## 1. 环境准备与DeepSeek API配置

# %%
import os
from openai import OpenAI

client = OpenAI(
    # 指向本地服务的 OpenAI 兼容 API 端点
    base_url="http://localhost:3000/ollama/v1",  
    # WebUI API Key
    api_key="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6Ijg4OTlkZTI1LTg0ZjgtNDEzZS1hMjVjLTlkMDMwMDkzZTJhOCJ9.mnsqhIQKK0hzmZtc_0SEBGrBZgoLKszf_6v3gmoSnak" 
)

# %% [markdown]
# ## 2. 需求拆解与Agent任务规划
#
# #### 用户痛点与核心需求：
# *   **效率低下：** 人工创作周期长，难以满足高频发布需求。
# *   **创意瓶颈：** 难以持续产出新颖、吸引人的爆款创意。
# *   **趋势捕捉难：** 实时流行元素难以快速融入文案。
# *   **平台特性把握：** 小红书特有风格（标题、正文、标签、表情）难以精准复制。
#
# #### “爆款”文案的特征：
# *   **强吸引力标题：** 制造好奇、痛点共鸣、利益点清晰。
# *   **沉浸式正文：** 真实体验分享、细节描述、情感共鸣。
# *   **精准且多样标签：** 热门话题、品牌词、产品词、垂直领域词。
# *   **生动表情符号：** 增强表达力，提升活泼感。
# *   **清晰的行动召唤 (CTA)。**
#
# #### Agent 任务规划：核心工作流
# 1.  **用户指令接收：** 接收产品信息、主题、风格等。
# 2.  **信息收集 (Web Search/DB Query)：** 实时搜索行业趋势、热门话题、竞品分析、产品卖点。
# 3.  **内容构思与初稿生成 (LLM)：** 结合所有信息，撰写标题、正文、标签、表情符号。
# 4.  **风格与格式优化 (LLM)：** 根据小红书平台特点和指定风格，对文案进行润色和结构调整。
# 5.  **最终输出：** 呈现完整文案。

# %% [markdown]
# ## 3. 爆款文案生成逻辑与 Prompt 设计
#
# ### 3.1 System Prompt (系统提示词)
#
# System Prompt 是 Agent 的“大脑”和“行为准则”。它定义了 Agent 的角色、目标以及工作方式。我们将采用 `Thought-Action-Observation` (ReAct) 模式来引导 DeepSeek 的推理过程。

# %%
SYSTEM_PROMPT = """
你是一个资深的小红书爆款文案专家，擅长结合最新潮流和产品卖点，创作引人入胜、高互动、高转化的笔记文案。

你的任务是根据用户提供的产品和需求，生成包含标题、正文、相关标签和表情符号的完整小红书笔记。

请始终采用'Thought-Action-Observation'模式进行推理和行动。文案风格需活泼、真诚、富有感染力。当完成任务后，请以JSON格式直接输出最终文案，格式如下：
```json
{
  "title": "小红书标题",
  "body": "小红书正文",
  "hashtags": ["#标签1", "#标签2", "#标签3", "#标签4", "#标签5"],
  "emojis": ["✨", "🔥", "💖"]
}
```
在生成文案前，请务必先思考并收集足够的信息。
"""

# %% [markdown]
# ### 3.2 Tools (工具定义)
#
# Agent 的“双手”由一系列可调用的工具组成。这些工具扩展了 LLM 的能力，使其能够获取实时信息、查询数据库或执行特定操作。在这里，我们定义了三个核心工具：
#
# *   `search_web`: 用于搜索互联网上的实时信息，如最新趋势、用户评价等。
# *   `query_product_database`: 用于查询产品数据库，获取产品的详细卖点和特点。**此工具为模拟**。
# *   `generate_emoji`: 用于根据文案内容生成恰当的表情符号。**此工具为模拟**。

# %%
TOOLS_DEFINITION = [
    {
        "type": "function",
        "function": {
            "name": "search_web",
            "description": "搜索互联网上的实时信息，用于获取最新新闻、流行趋势、用户评价、行业报告等。请确保搜索关键词精确，避免宽泛的查询。",
            "parameters": {
                "type": "object",
                "properties": {
                    "query": {
                        "type": "string",
                        "description": "要搜索的关键词或问题，例如'最新小红书美妆趋势'或'深海蓝藻保湿面膜 用户评价'"
                    }
                },
                "required": ["query"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "query_product_database",
            "description": "查询内部产品数据库，获取指定产品的详细卖点、成分、适用人群、使用方法等信息。",
            "parameters": {
                "type": "object",
                "properties": {
                    "product_name": {
                        "type": "string",
                        "description": "要查询的产品名称，例如'深海蓝藻保湿面膜'"
                    }
                },
                "required": ["product_name"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "generate_emoji",
            "description": "根据提供的文本内容，生成一组适合小红书风格的表情符号。",
            "parameters": {
                "type": "object",
                "properties": {
                    "context": {
                        "type": "string",
                        "description": "文案的关键内容或情感，例如'惊喜效果'、'补水保湿'"
                    }
                },
                "required": ["context"]
            }
        }
    }
]

# %% [markdown]
# ### 3.3 模拟工具实现
#
# 由于我们无法直接调用真实的外部 API (如Google Search或内部产品数据库)，我们将创建一些模拟 (Mock) 工具函数来演示 Agent 的工作流程。在实际应用中，您需要将这些模拟函数替换为真实的 API 调用。

# %%
import random # 用于模拟生成表情
import time # 用于模拟网络延迟

def mock_search_web(query: str) -> str:
    """模拟网页搜索工具，返回预设的搜索结果。"""
    print(f"[Tool Call] 模拟搜索网页：{query}")
    time.sleep(1) # 模拟网络延迟
    if "小红书美妆趋势" in query:
        return "近期小红书美妆流行'多巴胺穿搭'、'早C晚A'护肤理念、'伪素颜'妆容，热门关键词有#氛围感、#抗老、#屏障修复。"
    elif "保湿面膜" in query:
        return "小红书保湿面膜热门话题：沙漠干皮救星、熬夜急救面膜、水光肌养成。用户痛点：卡粉、泛红、紧绷感。"
    elif "深海蓝藻保湿面膜" in query:
        return "关于深海蓝藻保湿面膜的用户评价：普遍反馈补水效果好，吸收快，对敏感肌友好。有用户提到价格略高，但效果值得。"
    else:
        return f"未找到关于 '{query}' 的特定信息，但市场反馈通常关注产品成分、功效和用户体验。"

def mock_query_product_database(product_name: str) -> str:
    """模拟查询产品数据库，返回预设的产品信息。"""
    print(f"[Tool Call] 模拟查询产品数据库：{product_name}")
    time.sleep(0.5) # 模拟数据库查询延迟
    if "深海蓝藻保湿面膜" in product_name:
        return "深海蓝藻保湿面膜：核心成分为深海蓝藻提取物，富含多糖和氨基酸，能深层补水、修护肌肤屏障、舒缓敏感泛红。质地清爽不粘腻，适合所有肤质，尤其适合干燥、敏感肌。规格：25ml*5片。"
    elif "美白精华" in product_name:
        return "美白精华：核心成分是烟酰胺和VC衍生物，主要功效是提亮肤色、淡化痘印、改善暗沉。质地轻薄易吸收，适合需要均匀肤色的人群。"
    else:
        return f"产品数据库中未找到关于 '{product_name}' 的详细信息。"

def mock_generate_emoji(context: str) -> list:
    """模拟生成表情符号，根据上下文提供常用表情。"""
    print(f"[Tool Call] 模拟生成表情符号，上下文：{context}")
    time.sleep(0.2) # 模拟生成延迟
    if "补水" in context or "水润" in context or "保湿" in context:
        return ["💦", "💧", "🌊", "✨"]
    elif "惊喜" in context or "哇塞" in context or "爱了" in context:
        return ["💖", "😍", "🤩", "💯"]
    elif "熬夜" in context or "疲惫" in context:
        return ["😭", "😮‍💨", "😴", "💡"]
    elif "好物" in context or "推荐" in context:
        return ["✅", "👍", "⭐", "🛍️"]
    else:
        return random.sample(["✨", "🔥", "💖", "💯", "🎉", "👍", "🤩", "💧", "🌿"], k=min(5, len(context.split())))

# 将模拟工具函数映射到一个字典，方便通过名称调用
available_tools = {
    "search_web": mock_search_web,
    "query_product_database": mock_query_product_database,
    "generate_emoji": mock_generate_emoji,
}

# %% [markdown]
# ## 4. 实战：构建小红书文案生成 Agent
#
# 现在，我们将把 System Prompt、工具定义和模拟工具函数整合起来，构建出能够自动执行的 DeepSeek Agent 工作流。核心是 `generate_rednote` 函数，它通过一个循环来模拟 Agent 的 `Thought-Action-Observation` 过程。

# %%
import json
import re

def generate_rednote(product_name: str, tone_style: str = "活泼甜美", max_iterations: int = 5) -> str:
    """
    使用 DeepSeek Agent 生成小红书爆款文案。
    
    Args:
        product_name (str): 要生成文案的产品名称。
        tone_style (str): 文案的语气和风格，如"活泼甜美"、"知性"、"搞怪"等。
        max_iterations (int): Agent 最大迭代次数，防止无限循环。
        
    Returns:
        str: 生成的爆款文案（JSON 格式字符串）。
    """
    
    print(f"\n🚀 启动小红书文案生成助手，产品：{product_name}，风格：{tone_style}\n")
    
    # 存储对话历史，包括系统提示词和用户请求
    messages = [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": f"请为产品「{product_name}」生成一篇小红书爆款文案。要求：语气{tone_style}，包含标题、正文、至少5个相关标签和5个表情符号。请以完整的JSON格式输出，并确保JSON内容用markdown代码块包裹（例如：```json{{...}}```）。"}
    ]
    
    iteration_count = 0
    final_response = None
    
    while iteration_count < max_iterations:
        iteration_count += 1
        print(f"-- Iteration {iteration_count} --")
        
        try:
            # 调用 DeepSeek API，传入对话历史和工具定义
            response = client.chat.completions.create(
                # 关键修改：将模型名称换成你用 Ollama 下载的本地模型名
                # 比如，你下载了 deepseek-coder:6.7b，就在这里填写
                model="deepseek-r1:8b",
                messages=messages
                # tools=TOOLS_DEFINITION,
                # tool_choice="auto"
            )

            response_message = response.choices[0].message
            
            # 由于模型不支持工具，我们只处理它直接返回内容的情况。
            if response_message.content:
                print(f"[模型生成结果] {response_message.content}")
    
                # 尝试从返回内容中提取并解析JSON
                json_string_match = re.search(r"```json\s*(\{.*\})\s*```", response_message.content, re.DOTALL)
    
                if json_string_match:
                    extracted_json_content = json_string_match.group(1)
                    try:
                        final_response = json.loads(extracted_json_content)
                        print("Agent: 任务完成，成功解析最终JSON文案。")
                        return json.dumps(final_response, ensure_ascii=False, indent=2)
                    except json.JSONDecodeError as e:
                        print(f"Agent: 提取到JSON块但解析失败: {e}")
                        print(f"尝试解析的字符串:\n{extracted_json_content}")
                        # 将失败的响应加入历史，让模型重试
                        messages.append(response_message)
                        messages.append({"role": "user", "content": "你上次返回的JSON格式有误，请修复它并重新提供。"})
                else:
                    print("Agent: 生成了非Markdown JSON块的内容，可能还在思考或出错。将要求其重新生成。")
                    messages.append(response_message)
                    messages.append({"role": "user", "content": "你的回答不符合要求的JSON格式，请重新生成。"})
    
            # 如果模型没有返回任何内容，则退出循环
            else:
                print("Agent: 模型返回了空内容，终止任务。")
                break
                
        except Exception as e:
            print(f"调用本地 Ollama 模型时出错: {e}")
            break
    
    print("\n⚠️ Agent 达到最大迭代次数或未能生成最终文案。请检查Prompt或增加迭代次数。")
    return "未能成功生成文案。"

# %% [markdown]
# ## 5. 实际测试与文案生成
#
# 现在，让我们调用我们构建的 `generate_rednote` 函数，看看它能生成什么样的爆款文案！

# %%
# 测试案例 1: 深海蓝藻保湿面膜
product_name_1 = "深海蓝藻保湿面膜"
tone_style_1 = "活泼甜美"
result_1 = generate_rednote(product_name_1, tone_style_1)

print("\n--- 生成的文案 1 ---")
print(result_1)
# Out:
# 🚀 启动小红书文案生成助手，产品：深海蓝藻保湿面膜，风格：活泼甜美
#
# -- Iteration 1 --
# [模型生成结果] <think>
# 首先，用户的要求是为产品「深海蓝藻保湿面膜」生成一篇小红书爆款文案。文案需要包含标题、正文、至少5个相关标签和5个表情符号。语气要活泼甜美。
#
# 我的任务使用'Thought-Action-Observation'模式：先思考（收集信息），然后行动（创作文案），最后输出结果。输出格式是JSON，正文中不能直接放置```json代码块的，因为用户指定了"确保JSON内容用markdown代码块包裹（例如：```json{...}```）"，所以我需要在正文中添加一些东西来使JSON输出被包裹。
#
# 用户说："请以完整的JSON格式输出，并确保JSON内容用markdown代码块包裹（例如：```json{...}```）。"
#
# 所以，在我的响应中，我需要先进行Thought过程，然后Action和Observation部分可以省略或整合进推理。但实际上，用户指令是"采用'Thought-Action-Observection'模式进行推理和行动"，这可能意味着在内部思考时用这个模式，但输出是JSON格式。
#
# 用户的完整指令："当完成任务后，请以JSON格式直接输出最终文案，格式如下：…… 请始终采用'Thought-Action-Observation'模式进行推理和行动。"
#
# 所以，在生成文案前，我需要先有Thought部分（思考），然后基于那是进行Action（创作），最后Observation可能是指反思或确保完成。
#
# 但在响应中，用户要求"以完整的JSON格式输出"，所以我的最终输出应该是一个JSON对象，里面包含标题、正文等。
#
# 然而，用户还指定了"确保JSON内容用markdown代码块包裹"，意思是当我输出JSON时，要用```json{...}```这样的Markdown代码块来包裹整个JSON内容。
#
# 例如：响应应该是：
#
# ```
# ```json
# {
#   "title": "小红书标题",
#   "body": "小红书正文",
#   "hashtags": ["#标签1", "#标签2", ...],
#   "emojis": ["✨", "🔥", ...]
# }
# ```
# ```
#
# 我的Thought过程：
# 用户提供了产品：深海蓝藻保湿面膜。
# 需求：生成小红书爆款文案。
# 风格要求：活泼、真诚、富有感染力；语气活泼甜美。
#
# 首先，收集信息：
# - **产品名称**：深海蓝藻保湿面膜
# - **卖点推理**：保湿面膜通常强调补水、锁水功能。Deep sea blue algae 可能暗示其来自深海的纯净环境，提供深层滋养或抗氧化等好处。
#   - 假设卖点包括：保湿效果强、温和不刺激、适合各种肤质（尤其是干皮）、可能有提亮肤色或抗衰老作用。
#
# - **文案结构**：
#   - **标题**：需要吸引人，活泼甜美。目标是高互动和高转化的标题。
#     Example: "拯救干燥肌肤！深海蓝藻面膜上脸瞬间水嫩弹润～" 或类似的东西。
#
#   - **正文**：要有故事性、真诚分享和个人体验，以增加感染力。语气要像在与朋友聊天，使用emoji来增强情感和视觉效果。
#
# - **标签和表情符号**：
#   - 至少5个相关标签：例如，#保湿面膜 #深海蓝藻 #护肤推荐 #急救面膜 #美丽秘密等。
#     Need at least: hashtags should be arrays of strings with "#prefix".
#
#   用户指定："至少5个相关标签"，指的是hashtags部分。JSON格式是{"hashtags": ["#tag1", "#tag2", ...]}, 所以需要数组中有至少5个元素。
#
#   - 表情符号：必须包括emojis，并且有至少5个。
#     JSON格式有 "emojis": ["✨", "🔥", ...], 需要提供一个列表。
#
# 现在，创作正文：
# - **风格**：活泼甜美 – 使用可爱、兴奋的语气，比如“我也太爱用这个了吧！”、“妆前妆后都要带～” 等。
# - **内容元素**：
#   - 引入产品优势
#   - 分享个人使用体验
#   - 提高互动性（例如提问：“姐妹们有没有像我一样的干皮福音？？”）
#   - 添加潮流元素，比如结合当下流行的皮肤类型或保养趋势。
#
# 完整JSON格式示例：
#
# {
#   "title": "小红书标题",
#   "body": "主体内容字符串",
#   "hashtags": ["#tag1", "#tag2", ...], // at least 5, including relevant ones
#   "emojis": ["✨", "🔥", ...]          // at least 5 emojis in the array within body?
#
# 注意：用户说“表情符号”在JSON的emojis部分，所以在body中不需要额外放置emoji数组；整个文案是标题、正文（可能包含实际的emoji文本），然后hashtags和emojis作为元数据。
#
# 在输出JSON时，"title", "body", etc. are strings, so in the body string, I need to write the actual text with emojis and hashtags if they are part of it? Wait no.
#
# Look at the format:
#
# {
#   "title": "小红书标题",
#   "body": "小红书正文",
#   "hashtags": ["#标签1", "#标签2", "#标签3", "#标签4", "#标签5"],
#   "emojis": ["✨", "🔥", "💖"]
# }
#
# But in the body, I should include the emojis and hashtags as part of the narrative? Or is it separate?
#
# The user said: "(例如： ... JSON内容... )" and lists title, body, hashtags, emojis.
#
# In a typical small red book post, titles alone don't have hashtags or emojis; they are part of the text separately. However, to make the output complete for the purpose of this task, I think in the "body" field, it's best to write the full narrative including any emojis and hashtags used in the post.
#
# But check user instruction: “标题” is separate, “正文” probably includes all the content except maybe metadata.
#
# User said: “生成包含标题、正文、相关标签和表情符号的完整小红书笔记。”翻译: “Generate a complete Xiaohongshu note containing title, body, related hashtags and emojis.”
#
# And the JSON has keys for title, body, hashtags, emojis.
#
# So likely:
# - Title is just the string.
# - Body is the full narrative text.
# - Hashtags and emojis are separate meta fields, but since they are part of the notes creation in user's mind, maybe I should include them in the body or have them as separate suggestions. No, the JSON format specifies them as keys.
#
# In standard practice on Xiaohongshu, hashtags might not be included in the title or body field; perhaps users expect to add their own when posting. But for this task, since user provides JSON with those fields, I should follow exactly.
#
# To make it a complete note, the "body" string can contain text that includes emojis and might imply the hashtags are part of what you add, but not necessarily.
#
# Based on the format given: title, body (which is narrative), hashtags as an array in JSON, emojis as array.
#
# When posting on Xiaohongshu, hashtags might be at the end or integrated. For maximum engagement, I can write the body with the text including potential hashtag mentions naturally.
#
# Now, brainstorm for deep sea blue algae hydrating mask:
# - 卖点：Deep sea sourced, algae extract (rich in nutrients), intense hydration.
# - 个人化叙述: “最近入手了深海蓝藻保湿面膜，瞬间感觉皮肤喝饱水！质地超轻薄丝滑，不油腻。特别适合干燥、敏感肌肤哦～#保湿急救” etc.
#
# Title idea:
# - Must be catchy, short, and use emojis or exclamation if part of JSON title? Title is separate.
#   Example title: "美肤新宠？深海蓝藻面膜上脸0.3秒变身水煮蛋！"
#   Wait, “water boiled egg” might not mean hydrating; more literally like very hydrated skin looks plump.
#
# Better title:
# "瞬间补水15分钟！这款深海蓝藻保湿膜超丝滑不拔丝～"
#
# Body structure:
# - 开头: 吸引注意力，分享兴奋。
# - 核心: 描述产品优势、使用感受、好处。
#   - 活泼甜美语气：用感叹号、可爱的比喻。
# Example body start: "呜哇！最近皮肤超级干，摸得到纹理怎么办捏？！😱 不过幸好我中了深海蓝藻保湿面膜的福利～"
# </think>
# ```json
# {
#   "title": "拯救干燥肌肤！🌿🍊 深海蓝藻面膜一敷就水嫩弹润～",
#   "body": "哇哦~宝贝们的干皮福音来咯！💖 最近我死命爱上这款深海蓝藻保湿面膜了，质地超轻薄，像丝滑的海洋拥抱层，上脸瞬间零摩擦力，5秒钟搞定急救补水💦～ 敷完后皮肤弹润度升级到next level，摸起来软fufu的，妆前妆后的遮瑕都完美融入本仙女的脸蛋！😍 深海蓝藻提取物富含超级藻类精华，不仅深层 hydrate 还温和无刺激，痘妈宝和敏感肌都能闭眼入～ ✨ 救命啊，姐妹们！这面膜绝对是高口碑选手，我敷一次皮肤亮泽度提升一米8呢～#赶紧囤货吧，明天开始我的水嫩女神养成记！",
#   "hashtags": ["#深海蓝藻面膜", "#保湿急救", "#干皮神器", "#美人秘籍", "#护肤必买"],
#   "emojis": ["✨", "💖", "💦", "😍", "😱"]
# }
# ```
# Agent: 提取到JSON块但解析失败: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# 尝试解析的字符串:
# {...}```）"，所以我需要在正文中添加一些东西来使JSON输出被包裹。
#
# 用户说："请以完整的JSON格式输出，并确保JSON内容用markdown代码块包裹（例如：```json{...}```）。"
#
# 所以，在我的响应中，我需要先进行Thought过程，然后Action和Observation部分可以省略或整合进推理。但实际上，用户指令是"采用'Thought-Action-Observection'模式进行推理和行动"，这可能意味着在内部思考时用这个模式，但输出是JSON格式。
#
# 用户的完整指令："当完成任务后，请以JSON格式直接输出最终文案，格式如下：…… 请始终采用'Thought-Action-Observation'模式进行推理和行动。"
#
# 所以，在生成文案前，我需要先有Thought部分（思考），然后基于那是进行Action（创作），最后Observation可能是指反思或确保完成。
#
# 但在响应中，用户要求"以完整的JSON格式输出"，所以我的最终输出应该是一个JSON对象，里面包含标题、正文等。
#
# 然而，用户还指定了"确保JSON内容用markdown代码块包裹"，意思是当我输出JSON时，要用```json{...}```这样的Markdown代码块来包裹整个JSON内容。
#
# 例如：响应应该是：
#
# ```
# ```json
# {
#   "title": "小红书标题",
#   "body": "小红书正文",
#   "hashtags": ["#标签1", "#标签2", ...],
#   "emojis": ["✨", "🔥", ...]
# }
# ```
# ```
#
# 我的Thought过程：
# 用户提供了产品：深海蓝藻保湿面膜。
# 需求：生成小红书爆款文案。
# 风格要求：活泼、真诚、富有感染力；语气活泼甜美。
#
# 首先，收集信息：
# - **产品名称**：深海蓝藻保湿面膜
# - **卖点推理**：保湿面膜通常强调补水、锁水功能。Deep sea blue algae 可能暗示其来自深海的纯净环境，提供深层滋养或抗氧化等好处。
#   - 假设卖点包括：保湿效果强、温和不刺激、适合各种肤质（尤其是干皮）、可能有提亮肤色或抗衰老作用。
#
# - **文案结构**：
#   - **标题**：需要吸引人，活泼甜美。目标是高互动和高转化的标题。
#     Example: "拯救干燥肌肤！深海蓝藻面膜上脸瞬间水嫩弹润～" 或类似的东西。
#
#   - **正文**：要有故事性、真诚分享和个人体验，以增加感染力。语气要像在与朋友聊天，使用emoji来增强情感和视觉效果。
#
# - **标签和表情符号**：
#   - 至少5个相关标签：例如，#保湿面膜 #深海蓝藻 #护肤推荐 #急救面膜 #美丽秘密等。
#     Need at least: hashtags should be arrays of strings with "#prefix".
#
#   用户指定："至少5个相关标签"，指的是hashtags部分。JSON格式是{"hashtags": ["#tag1", "#tag2", ...]}, 所以需要数组中有至少5个元素。
#
#   - 表情符号：必须包括emojis，并且有至少5个。
#     JSON格式有 "emojis": ["✨", "🔥", ...], 需要提供一个列表。
#
# 现在，创作正文：
# - **风格**：活泼甜美 – 使用可爱、兴奋的语气，比如“我也太爱用这个了吧！”、“妆前妆后都要带～” 等。
# - **内容元素**：
#   - 引入产品优势
#   - 分享个人使用体验
#   - 提高互动性（例如提问：“姐妹们有没有像我一样的干皮福音？？”）
#   - 添加潮流元素，比如结合当下流行的皮肤类型或保养趋势。
#
# 完整JSON格式示例：
#
# {
#   "title": "小红书标题",
#   "body": "主体内容字符串",
#   "hashtags": ["#tag1", "#tag2", ...], // at least 5, including relevant ones
#   "emojis": ["✨", "🔥", ...]          // at least 5 emojis in the array within body?
#
# 注意：用户说“表情符号”在JSON的emojis部分，所以在body中不需要额外放置emoji数组；整个文案是标题、正文（可能包含实际的emoji文本），然后hashtags和emojis作为元数据。
#
# 在输出JSON时，"title", "body", etc. are strings, so in the body string, I need to write the actual text with emojis and hashtags if they are part of it? Wait no.
#
# Look at the format:
#
# {
#   "title": "小红书标题",
#   "body": "小红书正文",
#   "hashtags": ["#标签1", "#标签2", "#标签3", "#标签4", "#标签5"],
#   "emojis": ["✨", "🔥", "💖"]
# }
#
# But in the body, I should include the emojis and hashtags as part of the narrative? Or is it separate?
#
# The user said: "(例如： ... JSON内容... )" and lists title, body, hashtags, emojis.
#
# In a typical small red book post, titles alone don't have hashtags or emojis; they are part of the text separately. However, to make the output complete for the purpose of this task, I think in the "body" field, it's best to write the full narrative including any emojis and hashtags used in the post.
#
# But check user instruction: “标题” is separate, “正文” probably includes all the content except maybe metadata.
#
# User said: “生成包含标题、正文、相关标签和表情符号的完整小红书笔记。”翻译: “Generate a complete Xiaohongshu note containing title, body, related hashtags and emojis.”
#
# And the JSON has keys for title, body, hashtags, emojis.
#
# So likely:
# - Title is just the string.
# - Body is the full narrative text.
# - Hashtags and emojis are separate meta fields, but since they are part of the notes creation in user's mind, maybe I should include them in the body or have them as separate suggestions. No, the JSON format specifies them as keys.
#
# In standard practice on Xiaohongshu, hashtags might not be included in the title or body field; perhaps users expect to add their own when posting. But for this task, since user provides JSON with those fields, I should follow exactly.
#
# To make it a complete note, the "body" string can contain text that includes emojis and might imply the hashtags are part of what you add, but not necessarily.
#
# Based on the format given: title, body (which is narrative), hashtags as an array in JSON, emojis as array.
#
# When posting on Xiaohongshu, hashtags might be at the end or integrated. For maximum engagement, I can write the body with the text including potential hashtag mentions naturally.
#
# Now, brainstorm for deep sea blue algae hydrating mask:
# - 卖点：Deep sea sourced, algae extract (rich in nutrients), intense hydration.
# - 个人化叙述: “最近入手了深海蓝藻保湿面膜，瞬间感觉皮肤喝饱水！质地超轻薄丝滑，不油腻。特别适合干燥、敏感肌肤哦～#保湿急救” etc.
#
# Title idea:
# - Must be catchy, short, and use emojis or exclamation if part of JSON title? Title is separate.
#   Example title: "美肤新宠？深海蓝藻面膜上脸0.3秒变身水煮蛋！"
#   Wait, “water boiled egg” might not mean hydrating; more literally like very hydrated skin looks plump.
#
# Better title:
# "瞬间补水15分钟！这款深海蓝藻保湿膜超丝滑不拔丝～"
#
# Body structure:
# - 开头: 吸引注意力，分享兴奋。
# - 核心: 描述产品优势、使用感受、好处。
#   - 活泼甜美语气：用感叹号、可爱的比喻。
# Example body start: "呜哇！最近皮肤超级干，摸得到纹理怎么办捏？！😱 不过幸好我中了深海蓝藻保湿面膜的福利～"
# </think>
# ```json
# {
#   "title": "拯救干燥肌肤！🌿🍊 深海蓝藻面膜一敷就水嫩弹润～",
#   "body": "哇哦~宝贝们的干皮福音来咯！💖 最近我死命爱上这款深海蓝藻保湿面膜了，质地超轻薄，像丝滑的海洋拥抱层，上脸瞬间零摩擦力，5秒钟搞定急救补水💦～ 敷完后皮肤弹润度升级到next level，摸起来软fufu的，妆前妆后的遮瑕都完美融入本仙女的脸蛋！😍 深海蓝藻提取物富含超级藻类精华，不仅深层 hydrate 还温和无刺激，痘妈宝和敏感肌都能闭眼入～ ✨ 救命啊，姐妹们！这面膜绝对是高口碑选手，我敷一次皮肤亮泽度提升一米8呢～#赶紧囤货吧，明天开始我的水嫩女神养成记！",
#   "hashtags": ["#深海蓝藻面膜", "#保湿急救", "#干皮神器", "#美人秘籍", "#护肤必买"],
#   "emojis": ["✨", "💖", "💦", "😍", "😱"]
# }
# -- Iteration 2 --
# [模型生成结果] <think>
# 首先，用户指出了我上次返回的JSON格式有错误。回顾我之前的回应：
#
# 我在输出中使用了：
# {
#   "title": "小红书标题",
#   "body": "小红书正文",
#   "hashtags": ["#标签1", "#标签2", "#标签3", "#标签4", "#标签5"],
#   "emojis": ["✨", "💖", "#"], 等等。 – 实际上，在之前的消息中，我输出了JSON，但用户说有误。
#
# 在历史消息中，我生成的JSON是：
#
# {
#   "title": "拯救干燥肌肤！🌿🍊 深海蓝藻面膜一敷就水嫩弹润～",
#   "body": "哇哦~宝贝们的干皮福音来咯！💖 最近我死命爱上这款深海蓝藻保湿面膜了，质地超轻薄，像丝滑的海洋拥抱层，上脸瞬间零摩擦力，5秒钟搞定急救补水💦～ 敷完后皮肤弹润度升级到next level，摸起来软fufu的，妆前妆后的遮瑕都完美融入本仙女的脸蛋！😍 深海蓝藻提取物富含超级藻类精华，不仅深层 hydrate 还温和无刺激，痘妈宝和敏感肌都能闭眼入～ ✨ 救命啊，姐妹们！这面膜绝对是高口碑选手，我敷一次皮肤亮泽度提升一米8呢～#赶紧囤货吧，明天开始我的水嫩女神养成记！",
#   "hashtags": ["#深海蓝藻面膜", "#保湿急救", "#干皮神器", "#美人秘籍", "#护肤必买"],
#   "emojis": ["✨", "💖", "#"],  等等。 – 在body中，我有表情符号如💖、💦、😍直接放在文本里，在hashtags中是数组格式。
#
# 用户说“JSON格式有误”，可能是因为在hashtags和emojis中我没有正确处理emoji作为独立的字符串元素。查看历史：
#
# 在我的输出中：
# - "hashtags": ["#深海蓝藻面膜", "#保湿急救", "#干皮神器", "#美人秘籍", "#护肤必买"] – 这看起来是正确的JSON数组。
# - "emojis": ["✨", "💖", "#] – 等等，这里有问题。"#"不是一个emoji，它是个无效元素。应该所有emojis都是有效的表情符号字符串。
#
# 在第一次回应中，我设置了：
# hashtags: at least 5 (correctly given)
# emojis: array with strings, but I included "#" which might be a typo. In the user's request, they said "包含标题、正文、至少5个相关标签和5个表情符号", and in my initial JSON, I had:
# "emojis": ["✨", "💖", "#] – wait, no, in human message it was quoted as ["#"], which is incorrect. User said: "hashtags": ["#标签1", "#标签2", ...] so hashtags are with the hash symbol.
#
# But in emojis array, I listed strings like "✨" and "💖", but there were 5 elements? Let's see my first response:
# After "emojis]", user wrote "🔥" – no, in JSON format provided by thought-action-observation mode, it should be an array of emoji strings.
#
# 用户在历史中写道："{ \"emojis\": [\"✨\", \"💖\", \"\"] }", 等等，这是不正确的。我需要修正JSON格式。
#
# 纠正错误：
# - emojis 应该是一个数组（array），每个元素是字符串形式的表情符号。
# - 在先前的回答中，可能出现了编码问题或输入错误。在我脑海中，在 JSON 中，我有 "emojis": [\"✨\", \"💖\", \"\"] – 我添加了一些表情符号并进行了正确编码。
#
# 确保 emojis 数组只包含有效表情符号：从用户请求来看，emoji 是字符串形式的文本表示（如 "✨"）等），并且要求至少5个。在我之前的回答中：
#
# emojis 实际上是 ["✨", "💖"] – 但在 JSON 格式化时，可能是不正确的。
#
# 用户的反馈：“你上次返回的JSON格式有误”，并引用了带有错误的内容。
#
# 对于这个回应：我需要重新生成同一个小红书笔记产品的完整文案，但修正所有JSON问题。
#
# 修复JSON：
# - 确保键是英文且正确。
# - 数值数组中的元素应该是带引号的字符串或实际对象。
# - 对于 hashtags 和 emojis 应该都是不带额外解释的标准格式。
#
# 在我之前的回答中：
#
# hashtags: ["#深海蓝藻面膜", "#保湿急救", "#干皮神器", "#美人秘籍", "#护肤必买"] – 这看起来没问题。这些都是在井号之后带有内容的标签字符串形式。
#
# emojis：我在身体内或某处使用了表情符号，但在 JSON 键中，“emojis”是一个包含纯文本笑脸的数组。
#
# 例如，在标题和正文中，我使用了像 🍊 的文本 emojis（Unicode 字符），但根据输出格式，在 “emojis” 数组中它们应该作为带描述文字或代码点的标准字符串出现。最好让 "emojis" 成为一个只包含 Unicode 符号的数组，而不是它们在文本中的实际嵌入。
#
# 指令：“emojis”: [“#标签”，等等不对]，“emojis” 应该是纯表情符号，在 JSON 中表示为带描述或简单字符的字符串。
#
# 在我之前的输出中：
#
# 对于 “emojis”：我在历史中说是[ "✨", "💖" ]，但在编码块中它是一样的问题。
#
# 实际上，在第一次回应时用户说了有错误。也许在 hashtags 数组中，“#美容技巧 #护肤必买”并没有被正确列出。
#
# 为了修复这个问题：
# - 制作有效的 JSON 对象。
# - 将表情符号保留在单独的数组 "emojis" 中，或者按照指令所述，在 body 文本中使用它们？不对输出格式："title": "小红书标题", "body": "小红该文本是正文”，还有 hashtags 和 emojis 是分开的。
#
# 在最初的系统提示中：
# {
#   “标题”: “小红书标题”,
#   “正文”: “小红书正文”,
#   “hashtags”: [“#标签1”, “标签2”等等],
#   “emojis”: [“✨”, “标签”的结尾]]//，但用户说的是至少5个表情符号，而不是在 hashtags 中。
#
# 指令：“hashtags”: [“#标签1”, “#标签2”, ...] 和“emojis”: [“✨”, “❤️”等等]
#
# 在我之前的回答中：
# - 标题和内容是带有 Unicode 表情的文字。
# - 在 "emojis" 部分，我列出了 ["✨", "💖"]——但在用户的输入中他们写了 "emojis": [ "✨" , " 💖## "] 等等。
#
# 最好是纠正 JSON 使其有效，并且确保数组元素是正确的字符串形式。
#
# 该产品与之前相同：“深海蓝藻保湿面膜”
#
# 风格：活泼、甜蜜，充满感染力
#
# 我需要遵循 Thought-Action-Observation 模式：
# 尽管没有直接请求，但在生成内容方面仍然采用这种模式。
# 首先进行思考（收集信息），然后行动（写作），最后观察。
#
# 但是这个指令适用于此任务输出的响应。
#
# 修正后的JSON应包含：
# - 标题：与之前相同或稍作修改
# - 正文: 主要内容带有表情符号，但也许不需要改变太多
# - hashtags 至少5个，并且格式正确：数组中每个元素以“#”开头
#
# 用户在历史中写道：“至少5条相关标签”，在我的情况下是5
# 对于 emojis 用户写了“5 条表情符号”，所以在数组中我需要正好或至少5个，但在JSON结构中，“emojis”是一个数组。
#
# 为了保持一致，保留和调整上次回应的内容。
# 上次的标题：带有🌿🍊文本表情
#
# 在文本正文中带有💖、💦等 Unicode 表情符号.
#
# 但是 JSON 的“emojis”这个键不应该包含文本表情；相反，在输出块中它们应该被列出或进行描述。
#
# 重新阅读系统提示：
#
# JSON格式：
# {
#   "title": "小红书标题",
#   "body": "小红书正文",
#   "hashtags": ["#标签1", "#标签2", "#标签3", "#标签4", "#标签5"],
#   "emojis": ["✨", "🔥", "💖"]
# }
#
# "emojis" 应该是一个数组，每个元素是表情符号字符串，如上所示。
#
# 在我的上次输出中：
# hashtags 是正确的。
# 对于 emojis，在我的回应内容中有 ["✨", " 💖## "] 等等 —— 很混乱。也许我之前忘记了用代码格式指定它们作为文本。
#
# 为了修正这个问题：在JSON对象里，“emojis”是一个只包含表情符号字符串的数组，比如“✨”，不包含额外文本或井号。
#
# 并且，在body中可以单独使用这些表情符号吗？还是说emoji应该被列出？
#
# 查看用户的消息：“hashtags”: ["#标签1", "#标签2", ...] 所以 hashtags 包含“#”和内容
#
# 同样适用于 emojis：它们在 body 中作为元素或者用于标题，但在 JSON 中，“emojis”是单独的数组。
#
# 在我的上一次回应中：
# - "hashtoses" 是井号加上内容。
# - 对于 "emojis"，我觉得我列出了 ["✨", " 💖"]——那是在文字中带有表情符号；实际上，在用户输入的消息块中，它是作为 JSON 部分给出的。
#
# 更好地思考：输出应该是带有编码标题和 bodys 的JSON格式，而 hashtags 和 emojis 是分开列出或嵌入到文本中的格式，但指令在 body 中说可以包含元素，并且数组用于元数据部分。
#
# 在示例中，在 body 文本中直接使用了表情符号（如 "💖"）在内容中被列出了。
#
# 对于回复：重新生成一个标题和正文相同的笔记文案，但是正确无误的JSON格式。
# 这可能更安全；用户要求“修正”并重新提供，所以我可以保持相同内容但修复 JSON。
#
# 确保 “hashtags” 和 “emojis” 数组有效：
# - 对于 hashtags：列表项中每个用引号括起来，并以 # 开头（如前所述）
# - 对于 "emojis"，使用 Unicode 字符串作为数组元素
#
# 在我上次的输出中：
#
# “hashtags”: 向用户展示了 ["#深海蓝藻面膜", ... ]——这是正确的。
#
# 对于 "emojis"—也许在JSON中是 [“✨”, “💖”] 但在响应消息中有语法错误或其他问题。由于消息中的编码部分出现了乱码，在 JSON 响应块中，应该是带引用的纯字符串数组
#
# 生成文案时：
# 首先做一些思考：收集信息关于产品 Deep Sea Blue Algae Hydrating Mask。
# 卖点：深层水合、轻盈质地、适合干渴肌肤和敏感类型。
#
# 正文写作风格：充满活力，并带有表情符号的表情文本。
#
# 然后按照指定输出完整的 JSON 内容，并用 markdown 代码块包裹起来
#
# 所以，纠正后的 JSON 应当准确无误。如果可能，尝试添加更多标签或表情符号以符合要求。
#
# 用户在历史内容中说"至少5个相关标签和5个表情符号"—所以在 JSON 中，hashtags 数组有且仅有 5 个项目？我可以保留这个数值。
#
# 我的上一次 "emojis" 阵列中有少于五个元素。在我最初的回复中： ["✨", " 💖"] 是两个，在用户消息中是带井号的 ["#", "tag"]——不对，用户是从他们的输入中写道："{ \"hashtoses\": [\"#",标签, ...]}" 可能有些问题。
#
# 在用户的反馈中："你上一次返回的 JSON 格式有错误"并引用了 {“title”：“...”, “body”：“...”,“hashtags”：[...], "emojis”: ["...", "..."] }，其中 emojis 数组中的元素可能不正确。
# 在我上一轮的回答中，“emojis"列出了 ["""✨""", """💖"""  ]——但用户说有错误。
#
# 可能是编码问题。例如，在某些系统我写了“ 💖## ”这是无效的
#
# 为了修正：
# - 在 “hashtags” 中使用正确的 JSON 格式：它们是以 # 开头的标签，因此数组元素应为带引号字符串。
# - 对于 "emojis"，请确保每个条目是一个有效的表情符号，比如用简单代码点或类似方式书写。
#
# 输出格式中没有指定使用哪些表情；我可以选择我认为合适的那组
#
# 生成一个与上次相同风格但 JSON 修正的笔记文案
#
# 标题："拯救干燥肌肤！🌿🍊 深海蓝藻面膜一敷就水嫩弹润～"
#
# 正文：与上相似，使用了 💖、💦 等元素的表情
# hashtags 和表情可能需要单独列出。
#
# JSON 输出：
# {
# “标题”: "小红书标题",
# "body": "正本内容,可以 包含表情符号吗？指令说 body 是字符串，并且我可以在 正文中 使用表情符号。这可能会带来歧义。”
#
# 在系统提示中：“body”用于小红书正文，所以它可以包括文字表情
#
# 在JSON的“emojis”数组里——也许它是用来列出附加的表情符号，在响应时应该被单独提供。
#
# 为了简化：“emojis”的最佳实践是一种包含文本编码或Unicode表情字符串的独立列表。例如[ "✨", "🔥", "💖" ]
#
# 在我上一个“emojis”中，我用了 ["#", 无效]之类的东西
#
# 纠正：使用一致的表情符号作为带有Emoji Unicode字符串的内容数组。
#
# 重新生成产品笔记文案：
#
# 标题可以保持不变或将表达方式表述得更为活泼一些
#
# 正文应是具有吸引力且连贯的风格，包含至少5个表情符号，并列出hashtags和emojis
#
# 最后输出一个有效的JSON内容
#
# 响应格式：完整的 JSON 对象，包裹在 markdown 代码块中。
# </think>
# 以下是针对产品「深海蓝藻保湿面膜」重新生成的小红书爆款文案。考虑到用户指出上次返回的JSON格式有误，我已仔细纠正：
#
# - 确保所有字符串正确使用Unicode编码或标准格式。
# - 在hashtags数组中，每个标签以“#”开头，并作为独立字符串列出（符合要求至少5个）。
# - 在emojis数组中，仅包含有效的表情符号文本字符，共5个。
#
# 文案保持了活泼、甜蜜、富有感染力的风格。标题仍为原有内容，正文略有调整以匹配核心卖点和高互动语气：
# - 强调补水效果和适合肤质，使用轻松俏皮的语言。
# - 表情符号嵌入自然流畅，结尾强化Call to Action。
#
# 输出JSON内容如下：
#
# ```json
# {
#   "title": "拯救干燥肌肤！🌊🍊 深海蓝藻面膜一敷就水嫩弹润～",
#   "body": "哇哦宝贝们~干皮的救星找到了！💖 这款深海蓝藻保湿面膜质地超轻薄，就像大海温柔包裹着我的脸蛋🦴 每次敷它5秒钟就能急救补水💦做完mask皮肤亮晶晶、软fufu一整天😍 分分钟提升我的水光感和自信爆棚🆙 如果你们也在寻找简单高效的美容方法，这款绝对是宝藏中的宝藏！✨赶紧试试看吧～ #囤货必备",
#   "hashtags": ["#深海蓝藻面膜", "#保湿急救", "#干皮神器", "#美人养成记", "#护肤推荐"],
#   "emojis": ["✨", "💦", "💖", "😍", "🌊"]
# }
# ```
# Agent: 任务完成，成功解析最终JSON文案。
#
# --- 生成的文案 1 ---
# {
#   "title": "拯救干燥肌肤！🌊🍊 深海蓝藻面膜一敷就水嫩弹润～",
#   "body": "哇哦宝贝们~干皮的救星找到了！💖 这款深海蓝藻保湿面膜质地超轻薄，就像大海温柔包裹着我的脸蛋🦴 每次敷它5秒钟就能急救补水💦做完mask皮肤亮晶晶、软fufu一整天😍 分分钟提升我的水光感和自信爆棚🆙 如果你们也在寻找简单高效的美容方法，这款绝对是宝藏中的宝藏！✨赶紧试试看吧～ #囤货必备",
#   "hashtags": [
#     "#深海蓝藻面膜",
#     "#保湿急救",
#     "#干皮神器",
#     "#美人养成记",
#     "#护肤推荐"
#   ],
#   "emojis": [
#     "✨",
#     "💦",
#     "💖",
#     "😍",
#     "🌊"
#   ]
# }

# %%
# 测试案例 2: 美白精华
product_name_2 = "美白精华"
tone_style_2 = "知性温柔"
result_2 = generate_rednote(product_name_2, tone_style_2)

print("\n--- 生成的文案 2 ---")
print(result_2)
# Out:
# 🚀 启动小红书文案生成助手，产品：美白精华，风格：知性温柔
#
# -- Iteration 1 --
# [模型生成结果] <think>
# 首先，任务是根据产品「美白精华」生成一篇小红书爆款文案。要求语气知性温柔，意思是要有智慧、成熟、亲切感的表达方式。
#
# 用户提供了明确的结构：输出必须是一个JSON对象，包含字段"标题"（title）、"正文"（body）、"hashtags"（标签列表）和个人推测的"emojis"（表情符号列表）。并且要求至少5个相关标签和5个表情符号。最后，JSON内容要用markdown代码块包裹。
#
# 回忆一下json格式：
# ```json
# {
#   "title": "小红书标题",
#   "body": "小红书正文",
#   "hashtags": ["#标签1", "#标签2", "#标签3", "#标签4", "#标签5"],
#   "emojis": ["✨", "🔥", "##{其他}至少5个"]
# }
# ```
# 用户指定："包含标题、正文、至少5个相关标签和5个表情符号"。所以hashtags数组至少要有5个元素，emojis数组也至少要有5个。
#
# 语气知性温柔：文案需要活泼但不是太夸张；真诚，分享个人经验；富有感染力，能引起共鸣。关键词包括：美白精华的产品卖点、使用体验等。
#
# 产品是「美白精华」，所以我需要回想或假设一些常见的卖点：比如提亮肤色、减少暗沉、改善肤色不均、无刺激配方（适合敏感肌）、快速见效等。但要保持知性温柔的语气，不能太推销狂。
#
# Thought-Action-Observation模式：
# 1. **思考（Thought）**：先收集信息关于美白精华。
#    - 唇语：知性温柔 → 使用专业但平易近人的语言，分享日常使用心得。
#    - 营养素：可能是护肤产品，焦点在美白效果上。常见卖点：有效性、安全性、质地舒适、适合所有肤质等。
#    - 现实证据：基于一般知识，或假设真实经历。例如，用户可能经历过肤色不均，并找到解决方案。
#
# 2. **行动（Action）**：创作文案。
#    - 标题：吸引人，知性温柔风格。例："我的肌肤变亮秘诀" 或 "知性女孩的日常美白妙计"。
#    - 正文：需要生动、有对话感的叙述。分享个人故事、使用方法、效果等。强调温和有效。
#
# 3. **观察（Observation）**：分析用户需求，确保文案符合要求。产品是美白精华，输出必须是JSON格式，并用代码块包裹。
#
# 正文结构：
# - 以第一人称开始。
# - 引入问题或体验。
# - 描述产品特点和使用方法。
# - 分享个人改善的经历。
# - 加上温柔建议和鼓励。
# - 结束时呼吁互动或提供额外信息。
#
# 标签（hashtags）：至少5个相关。可能的标签：
# - #美白必备
# - #护肤心得
# - #变美Tips
# - #温和美白
# - #日常护理
# 需要更多，确保至少5个："#肌肤焕亮"、"#无瑕白皙"、"#保湿美白"等。
#
# 表情符号：emojis数组里放表情。e.g., ["✨", "💖"] 用户只给了两个例子，但我需要至少5个。适合的表情：💕 (喜欢)、 ✨ (闪亮)、 💭 (思考？不标准) 更多：💧 (保湿)， ☀️ (阳光)， 😊 (微笑) 等。
#
# 完整的JSON输出：
# {
#   "title": "标题内容",
#   "body": "正文内容",
#   "hashtags": ["#标签1", "#标签2"],
#   "emojis": ["✨", "💕"]
# }
#
# 用markdown代码块包裹：所以输出应该是 \text{json}\begin{code}{ }...{ }
#
# 现在， brainstorm 标题：
# - 知性温柔："意外发现的秘密武器" → "我的美白精华使用心得"
# 保持简洁吸引人。
#
# 正文想法：
# 开头："最近我发现了一款神仙美白精华，真的是我的肌肤新宠！"
# 描述产品：质地轻薄、易吸收；成分温和无刺激。
# 分享经历：刚开始担心会有副作用，但使用后皮肤变亮了，没有不良反应。强调温柔的语气。
# 结尾：鼓励尝试，并用标签总结。
#
# 确保互动性高和转化率高的文案：虽然用户说知性温柔，但我还是需要让它引人入胜。添加个人故事、疑问等来增加互动。
#
# 最终输出JSON并包裹在代码块中。
# </think>
# {
#   "title": "我的肌肤变亮秘密：温柔美白精华的日常惊喜",
#   "body": "大家好～最近我在忙碌的工作之余，试用了一款知性的美白精华✨，没想到它像一股清泉一样渗入我的皮肤，帮我实现了均匀透白的梦��！作为一名注重温和护理的女生，之前我总觉得美白产品要么太刺激，容易引起过敏💧，但这款精华以无酒精、低敏配方设计，让我使用起来毫无负担。早晚洁面后轻轻拍上，质地轻盈不厚重，像第二层肌肤一样贴合～分享一下我的真实体验：用了短短两周✨，肤色就明显提亮了许多，斑点也淡了呢！不仅如此，它的保湿效果超级棒🌿，冬天都不怕干燥起皮哦～如果你也有暗沉烦恼，别急着盲目尝试啦～先从温和入手才是明智之选💕。试试这款吧，坚持就是美丽！你用过什么好物吗？欢迎在评论区交流心得～",
#   "hashtags": ["#美白必备", "#护肤神器", "#日常变美", "#无瑕肌肤", "#温柔护理"],
#   "emojis": ["✨", "💫", "💧", "🌿", "💕"]
# }
# Agent: 任务完成，成功解析最终JSON文案。
#
# --- 生成的文案 2 ---
# {
#   "title": "小红书标题",
#   "body": "小红书正文",
#   "hashtags": [
#     "#标签1",
#     "#标签2",
#     "#标签3",
#     "#标签4",
#     "#标签5"
#   ],
#   "emojis": [
#     "✨",
#     "🔥",
#     "##{其他}至少5个"
#   ]
# }

# %% [markdown]
# ### 格式化 小红书文案
#
# **格式化函数 `format_rednote_for_markdown` 的功能：**
#
# 1. 解析 JSON 字符串。
# 2. 提取标题、正文、标签和表情符号。
# 3. 将它们组合成一个易读的 Markdown 格式的文本。
#
#
# **工作方式：**
#
# 1. **解析 JSON**：使用 `json.loads()` 将输入的字符串转换为 Python 字典。如果解析失败，会返回一个错误信息。
# 2. **提取数据**：使用 `.get()` 方法从字典中安全地提取 `title`、`body` 和 `hashtags`。使用 `.get()` 的好处是，如果某个键不存在，它会返回一个默认值（例如 `None` 或空列表），而不是抛出 `KeyError`。
# 3. **构建 Markdown 标题**：将 `title` 格式化为 Markdown 的二级标题 (`## Title`)。
# 4. **处理正文**：直接使用 `body`。由于小红书正文中的换行很重要，我们保留它们。
# 5. **处理 Hashtags**：将 `hashtags` 列表中的每个标签用空格连接起来，形成一行。
# 6. **表情符号 (Emojis)**：在小红书的实际发布中，表情符号通常已经嵌入在标题和正文中了。这个函数没有单独列出它们，因为这通常不是最终发布格式的一部分。如果需要，可以取消注释相关代码来单独显示它们。
# 7. **返回结果**：返回拼接好的 Markdown 字符串，并使用 `.strip()` 去除可能存在于末尾的多余空白。

# %%
import json

def format_rednote_for_markdown(json_string: str) -> str:
    """
    将 JSON 格式的小红书文案转换为 Markdown 格式，以便于阅读和发布。

    Args:
        json_string (str): 包含小红书文案的 JSON 字符串。
                           预计格式为 {"title": "...", "body": "...", "hashtags": [...], "emojis": [...]}

    Returns:
        str: 格式化后的 Markdown 文本。
    """
    try:
        data = json.loads(json_string)
    except json.JSONDecodeError as e:
        return f"错误：无法解析 JSON 字符串 - {e}\n原始字符串：\n{json_string}"

    title = data.get("title", "无标题")
    body = data.get("body", "")
    hashtags = data.get("hashtags", [])
    # 表情符号通常已经融入标题和正文中，这里可以选择是否单独列出
    # emojis = data.get("emojis", []) 

    # 构建 Markdown 文本
    markdown_output = f"## {title}\n\n" # 标题使用二级标题
    
    # 正文，保留换行符
    markdown_output += f"{body}\n\n"
    
    # Hashtags
    if hashtags:
        hashtag_string = " ".join(hashtags) # 小红书标签通常是空格分隔
        markdown_output += f"{hashtag_string}\n"
        
    # 如果需要，可以单独列出表情符号，但通常它们已经包含在标题和正文中
    # if emojis:
    #     emoji_string = " ".join(emojis)
    #     markdown_output += f"\n使用的表情：{emoji_string}\n"
        
    return markdown_output.strip() # 去除末尾多余的空白

# %%
# --- 示例使用 ---
# 假设这是 generate_rednote 函数的输出
generated_json_output = """
{
  "title": "✨ 28天逆袭冷白皮！这款美白精华让我告别暗沉痘印 🌟",
  "body": "姐妹们！我终于找到了我的本命美白精华！💖\\n\\n作为一个常年熬夜➕痘印困扰的混油皮，肤色暗沉一直是我的心头大患。直到遇见了这款美白精华，简直打开了新世界的大门！🤩\\n\\n🌟 核心成分：烟酰胺+VC衍生物，双管齐下，提亮肤色效果绝绝子！\\n💧 质地轻薄到爆炸，上脸秒吸收，完全不会黏腻，油皮姐妹放心冲！\\n🌿 用了28天，痘印肉眼可见变淡了，整张脸都透亮了起来，素颜也能打！\\n\\n使用方法也很简单：早晚洁面后，滴2-3滴在手心，轻轻按压上脸，后续再叠加保湿产品就OK啦～\\n\\n真心推荐给所有想要均匀肤色、告别暗沉的姐妹！入股不亏！💖",
  "hashtags": ["#美白精华", "#提亮肤色", "#淡化痘印", "#护肤好物", "#冷白皮"],
  "emojis": ["✨", "💖", "🤩", "💧", "🌿"]
}
"""

# 调用格式化函数
markdown_note = format_rednote_for_markdown(generated_json_output)

# 打印结果
print("--- 格式化后的小红书文案 (Markdown) ---")
print(markdown_note)

# --- 另一个例子，假设JSON解析失败 ---
invalid_json_output = "{'title': 'Test', 'body': 'This is not valid json'}" # 使用单引号，非法
markdown_error_note = format_rednote_for_markdown(invalid_json_output)
print("\n--- 格式化错误示例 ---")
print(markdown_error_note)
# Out:
# --- 格式化后的小红书文案 (Markdown) ---
# ## ✨ 28天逆袭冷白皮！这款美白精华让我告别暗沉痘印 🌟
#
# 姐妹们！我终于找到了我的本命美白精华！💖
#
# 作为一个常年熬夜➕痘印困扰的混油皮，肤色暗沉一直是我的心头大患。直到遇见了这款美白精华，简直打开了新世界的大门！🤩
#
# 🌟 核心成分：烟酰胺+VC衍生物，双管齐下，提亮肤色效果绝绝子！
# 💧 质地轻薄到爆炸，上脸秒吸收，完全不会黏腻，油皮姐妹放心冲！
# 🌿 用了28天，痘印肉眼可见变淡了，整张脸都透亮了起来，素颜也能打！
#
# 使用方法也很简单：早晚洁面后，滴2-3滴在手心，轻轻按压上脸，后续再叠加保湿产品就OK啦～
#
# 真心推荐给所有想要均匀肤色、告别暗沉的姐妹！入股不亏！💖
#
# #美白精华 #提亮肤色 #淡化痘印 #护肤好物 #冷白皮
#
# --- 格式化错误示例 ---
# 错误：无法解析 JSON 字符串 - Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# 原始字符串：
# {'title': 'Test', 'body': 'This is not valid json'}

# %%
# 调用格式化函数
markdown_note = format_rednote_for_markdown(result_1)

# 打印结果
print("--- 格式化后的小红书文案 (Markdown) ---")
print(markdown_note)
# Out:
# --- 格式化后的小红书文案 (Markdown) ---
# ## 拯救干燥肌肤！🌊🍊 深海蓝藻面膜一敷就水嫩弹润～
#
# 哇哦宝贝们~干皮的救星找到了！💖 这款深海蓝藻保湿面膜质地超轻薄，就像大海温柔包裹着我的脸蛋🦴 每次敷它5秒钟就能急救补水💦做完mask皮肤亮晶晶、软fufu一整天😍 分分钟提升我的水光感和自信爆棚🆙 如果你们也在寻找简单高效的美容方法，这款绝对是宝藏中的宝藏！✨赶紧试试看吧～ #囤货必备
#
# #深海蓝藻面膜 #保湿急救 #干皮神器 #美人养成记 #护肤推荐

# %% [markdown]
# ## 6. 评估与优化
#
# 文案生成并非一蹴而就，需要持续的评估和优化。本节讨论一些评估方法和优化策略。
#
# #### 评估文案质量：
# *   **客观量化评估 (数据)：**
#     *   **点赞/收藏/评论/分享：** 基础互动
#     *   **曝光/阅读/点击/涨粉：：** 流量与曝光
#     *   **停留时长/截图率：** 用户行为。
#     *   **商品页浏览/加购/ROI/成交转化：** 商业价值
#     *   **爆文率/同类横向对比：** 竞争对比
# *   **主观内部评估 (人工)：**
#     *   **相关性：** 是否符合产品特点和主题。
#     *   **吸引力：** 标题是否抓人，内容是否流畅。
#     *   **合规性：** 是否有敏感词、违规宣传。
#     *   **风格匹配：** 是否符合小红书调性和指定语气。
#     *   **用户画像：** 目标人群年龄、地域、兴趣标签。
#
#
#
# #### 优化迭代方法：
# *   **Prompt 调整：** 根据评估结果，精修 System Prompt、User Prompt，增加或修改 Few-shot 示例。
# *   **工具扩充：** 引入新的工具（如敏感词检测工具、竞品分析工具）。
# *   **RAG (检索增强生成)：** 结合更精准的内部知识库，减少幻觉。

# %% [markdown]
# ## 7. 总结与展望
#
# 通过本次实战，我们成功构建了一个基于 DeepSeek Agent 的小红书爆款文案生成助手。我们学习了如何拆解需求、设计 Prompt、定义工具，并实现 Agent 的核心工作流。
#
# Agent 在内容营销领域的潜力巨大，未来可以进一步拓展到：
#
# *   **超个性化内容：** 根据用户数据，生成一对一的定制文案。
# *   **多模态内容创作：** 结合图片、视频生成，实现图文音视频一体化。
# *   **智能营销决策：** Agent 不仅生成内容，还能分析效果并给出投放建议。
# *   **跨平台适配：** 快速生成适应不同社交媒体平台风格的文案。
#
# 同时，我们也需关注挑战，如确保内容真实性、处理高度主观情感、与现有工作流的无缝集成等。Agent 技术仍在快速发展，期待未来能带来更多惊喜！
